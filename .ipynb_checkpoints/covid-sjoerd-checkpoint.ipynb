# %% [markdown]
# # ML COVID - Jochem & Sjoerd

# %%
import pandas as pd
import missingno as msno
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def toBool(any):
    return 1.00 if bool(any) else 0.00


# Read csv and convert test features to bool
df = pd.read_csv('./covid.csv', low_memory=False, converters={'tests_units': toBool})
# Display all columns setting 
pd.set_option('display.max_columns', None)


labels = ['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths','new_deaths', 'new_deaths_smoothed', 
                    'total_cases_per_million', 'new_cases_per_million','new_cases_smoothed_per_million', 
                    'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million']

# %%
## Instellingen voor een correctie plot.
def plot_corr(df, size=81):
    corr = df.corr()    # data frame correlation function
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)   # color code the rectangles by correlation value
    plt.xticks(range(len(corr.columns)), corr.columns)  # draw x tick marks
    plt.yticks(range(len(corr.columns)), corr.columns)  # draw y tick marks

# %%
test = df.sample(n = 100)

## Alle Smooth columns verwijderen aangezien ze een afronding zijn.
del test['new_cases_smoothed']
del test['new_deaths_smoothed']
del test['new_tests_smoothed']
del test['new_cases_smoothed_per_million']
del test['new_deaths_smoothed_per_million']
del test['new_tests_smoothed_per_thousand']

# %%
## Visuele tabel wat de correlatie laat zien tussen data.
## De GELER het vakje, de MEER correlatie er tussen zit
## Een correlatie laat zien dat tussen de twee waardes een verband zit, per 'stap' die waarde 1 omhoog of omlaag gaat, gaat waarde 2 ook omhoog of omlaag.

plot_corr(test)

# %%
## Tabel wat een correlation value laat zien tussen data
test.corr()
# Out:
#                             total_cases  new_cases  total_deaths  new_deaths  \
# total_cases                    1.000000   0.461499      0.849142    0.615136
# new_cases                      0.461499   1.000000      0.426486    0.805784
# total_deaths                   0.849142   0.426486      1.000000    0.716101
# new_deaths                     0.615136   0.805784      0.716101    1.000000
# total_cases_per_million        0.457614   0.221059      0.386290    0.241815
# new_cases_per_million          0.119559   0.493252      0.086811    0.299458
# total_deaths_per_million       0.349031   0.153642      0.528648    0.257931
# new_deaths_per_million         0.304132   0.554617      0.343194    0.608241
# new_tests                      0.554196   0.284182      0.421615    0.214625
# total_tests                    0.781275   0.285898      0.721514    0.410084
# total_tests_per_thousand       0.391207   0.099493      0.398011    0.132017
# new_tests_per_thousand         0.169160   0.058403      0.183950    0.034020
# tests_per_case                -0.024557  -0.019321     -0.010113   -0.030165
# positive_rate                  0.327861   0.315580      0.277350    0.300829
# tests_units                    0.337481   0.292779      0.298616    0.232915
# stringency_index              -0.007466   0.167985     -0.023093    0.138647
# population                     0.454136   0.386775      0.308291    0.338451
# population_density             0.006119   0.035494     -0.055247   -0.035040
# median_age                    -0.040078  -0.000691      0.028288    0.024954
# aged_65_older                 -0.122046  -0.061524     -0.023493   -0.020315
# aged_70_older                 -0.124110  -0.057119     -0.022600   -0.010099
# gdp_per_capita                -0.036494  -0.051078     -0.007679   -0.060098
# extreme_poverty               -0.082032  -0.128483     -0.131498   -0.139489
# cardiovasc_death_rate         -0.015435  -0.085665     -0.063618   -0.059618
# diabetes_prevalence            0.022010  -0.037255     -0.036974   -0.054409
# female_smokers                -0.168224  -0.174800     -0.076752   -0.125526
# male_smokers                  -0.006830   0.070914     -0.096886   -0.056909
# handwashing_facilities        -0.026241  -0.038411     -0.017790   -0.039713
# hospital_beds_per_thousand    -0.141119  -0.154139     -0.077600   -0.148543
# life_expectancy               -0.060717   0.075921      0.014391    0.056244
# human_development_index        0.024508   0.022887      0.098251    0.047348
#
#                             total_cases_per_million  new_cases_per_million  \
# total_cases                                0.457614               0.119559
# new_cases                                  0.221059               0.493252
# total_deaths                               0.386290               0.086811
# new_deaths                                 0.241815               0.299458
# total_cases_per_million                    1.000000               0.567587
# new_cases_per_million                      0.567587               1.000000
# total_deaths_per_million                   0.715546               0.281730
# new_deaths_per_million                     0.457096               0.577234
# new_tests                                  0.222898               0.003552
# total_tests                                0.344431              -0.000780
# total_tests_per_thousand                   0.287526               0.029761
# new_tests_per_thousand                     0.126243               0.147013
# tests_per_case                            -0.046001              -0.046258
# positive_rate                              0.095814               0.167152
# tests_units                                0.030819               0.071092
# stringency_index                          -0.083506               0.091628
# population                                -0.055921              -0.088389
# population_density                         0.168203               0.027525
# median_age                                 0.082366               0.058116
# aged_65_older                              0.011747              -0.058117
# aged_70_older                             -0.001035              -0.068219
# gdp_per_capita                             0.083399               0.248528
# extreme_poverty                           -0.122479              -0.090139
# cardiovasc_death_rate                     -0.148326              -0.151668
# diabetes_prevalence                        0.106850               0.239319
# female_smokers                             0.046538              -0.052486
# male_smokers                              -0.038231              -0.089824
# handwashing_facilities                     0.128168               0.080274
# hospital_beds_per_thousand                -0.005711              -0.083610
# life_expectancy                            0.188150               0.181098
# human_development_index                    0.207626               0.174315
#
#                             total_deaths_per_million  new_deaths_per_million  \
# total_cases                                 0.349031                0.304132
# new_cases                                   0.153642                0.554617
# total_deaths                                0.528648                0.343194
# new_deaths                                  0.257931                0.608241
# total_cases_per_million                     0.715546                0.457096
# new_cases_per_million                       0.281730                0.577234
# total_deaths_per_million                    1.000000                0.351691
# new_deaths_per_million                      0.351691                1.000000
# new_tests                                   0.191440                0.043696
# total_tests                                 0.315528                0.126495
# total_tests_per_thousand                    0.352157                0.038411
# new_tests_per_thousand                      0.172435               -0.020153
# tests_per_case                             -0.013812               -0.050829
# positive_rate                               0.146882                0.226126
# tests_units                                 0.096450                0.075176
# stringency_index                           -0.052798                0.175538
# population                                 -0.032383                0.012117
# population_density                         -0.076574               -0.106091
# median_age                                  0.115220                0.017250
# aged_65_older                               0.131778                0.012786
# aged_70_older                               0.135741                0.013047
# gdp_per_capita                              0.010064               -0.085597
# extreme_poverty                            -0.152556               -0.095019
# cardiovasc_death_rate                      -0.159460               -0.084711
# diabetes_prevalence                        -0.052624               -0.014859
# female_smokers                              0.206998               -0.015940
# male_smokers                               -0.018657               -0.136674
# handwashing_facilities                      0.043282                0.013972
# hospital_beds_per_thousand                  0.083089               -0.085780
# life_expectancy                             0.159765                0.022881
# human_development_index                     0.205260                0.040168
#
#                             new_tests  total_tests  total_tests_per_thousand  \
# total_cases                  0.554196     0.781275                  0.391207
# new_cases                    0.284182     0.285898                  0.099493
# total_deaths                 0.421615     0.721514                  0.398011
# new_deaths                   0.214625     0.410084                  0.132017
# total_cases_per_million      0.222898     0.344431                  0.287526
# new_cases_per_million        0.003552    -0.000780                  0.029761
# total_deaths_per_million     0.191440     0.315528                  0.352157
# new_deaths_per_million       0.043696     0.126495                  0.038411
# new_tests                    1.000000     0.863201                  0.670239
# total_tests                  0.863201     1.000000                  0.731803
# total_tests_per_thousand     0.670239     0.731803                  1.000000
# new_tests_per_thousand       0.514755     0.433283                  0.783367
# tests_per_case               0.160092     0.077587                  0.422433
# positive_rate                0.177773     0.167335                  0.065321
# tests_units                  0.512527     0.417849                  0.447429
# stringency_index             0.024471    -0.021667                 -0.003821
# population                   0.403435     0.330375                  0.040538
# population_density           0.066180    -0.003957                  0.013101
# median_age                   0.123837     0.103525                  0.263652
# aged_65_older                0.040508     0.027795                  0.224934
# aged_70_older                0.035364     0.022135                  0.226747
# gdp_per_capita               0.141813     0.103372                  0.242348
# extreme_poverty             -0.134494    -0.120420                 -0.124954
# cardiovasc_death_rate       -0.111043    -0.083654                 -0.213302
# diabetes_prevalence          0.100487     0.073467                  0.093215
# female_smokers              -0.107113    -0.105047                  0.087803
# male_smokers                -0.025900    -0.112272                 -0.169773
# handwashing_facilities      -0.023443    -0.019634                  0.000107
# hospital_beds_per_thousand  -0.019164    -0.065877                  0.057029
# life_expectancy              0.142489     0.081313                  0.222989
# human_development_index      0.195705     0.175225                  0.330082
#
#                             new_tests_per_thousand  tests_per_case  \
# total_cases                               0.169160       -0.024557
# new_cases                                 0.058403       -0.019321
# total_deaths                              0.183950       -0.010113
# new_deaths                                0.034020       -0.030165
# total_cases_per_million                   0.126243       -0.046001
# new_cases_per_million                     0.147013       -0.046258
# total_deaths_per_million                  0.172435       -0.013812
# new_deaths_per_million                   -0.020153       -0.050829
# new_tests                                 0.514755        0.160092
# total_tests                               0.433283        0.077587
# total_tests_per_thousand                  0.783367        0.422433
# new_tests_per_thousand                    1.000000        0.595646
# tests_per_case                            0.595646        1.000000
# positive_rate                             0.131665       -0.059101
# tests_units                               0.506596        0.218789
# stringency_index                          0.058247        0.022059
# population                               -0.028381       -0.039084
# population_density                        0.082331       -0.000076
# median_age                                0.250472        0.103173
# aged_65_older                             0.124000        0.143548
# aged_70_older                             0.128582        0.134882
# gdp_per_capita                            0.431646        0.087432
# extreme_poverty                          -0.105025        0.015655
# cardiovasc_death_rate                    -0.246813       -0.143020
# diabetes_prevalence                       0.200396       -0.040206
# female_smokers                            0.056801        0.069572
# male_smokers                             -0.147492       -0.208319
# handwashing_facilities                    0.015616       -0.015797
# hospital_beds_per_thousand                0.056031       -0.002825
# life_expectancy                           0.272576        0.125830
# human_development_index                   0.389758        0.173331
#
#                             positive_rate  tests_units  stringency_index  \
# total_cases                      0.327861     0.337481         -0.007466
# new_cases                        0.315580     0.292779          0.167985
# total_deaths                     0.277350     0.298616         -0.023093
# new_deaths                       0.300829     0.232915          0.138647
# total_cases_per_million          0.095814     0.030819         -0.083506
# new_cases_per_million            0.167152     0.071092          0.091628
# total_deaths_per_million         0.146882     0.096450         -0.052798
# new_deaths_per_million           0.226126     0.075176          0.175538
# new_tests                        0.177773     0.512527          0.024471
# total_tests                      0.167335     0.417849         -0.021667
# total_tests_per_thousand         0.065321     0.447429         -0.003821
# new_tests_per_thousand           0.131665     0.506596          0.058247
# tests_per_case                  -0.059101     0.218789          0.022059
# positive_rate                    1.000000     0.564876          0.245275
# tests_units                      0.564876     1.000000          0.128761
# stringency_index                 0.245275     0.128761          1.000000
# population                       0.462785     0.374548          0.157587
# population_density               0.058811     0.135897         -0.036555
# median_age                      -0.079082     0.146274         -0.301287
# aged_65_older                   -0.163375     0.073667         -0.373370
# aged_70_older                   -0.151986     0.077124         -0.365112
# gdp_per_capita                   0.045828     0.221776         -0.228532
# extreme_poverty                  0.053644     0.013606         -0.002475
# cardiovasc_death_rate           -0.063887    -0.265660          0.146672
# diabetes_prevalence             -0.024308    -0.058325          0.167912
# female_smokers                  -0.212329    -0.091762         -0.396350
# male_smokers                     0.086560    -0.104579          0.074683
# handwashing_facilities          -0.142791    -0.089922          0.081949
# hospital_beds_per_thousand      -0.247815    -0.051322         -0.343869
# life_expectancy                 -0.009512     0.138804         -0.264587
# human_development_index         -0.049079     0.212812         -0.293996
#
#                             population  population_density  median_age  \
# total_cases                   0.454136            0.006119   -0.040078
# new_cases                     0.386775            0.035494   -0.000691
# total_deaths                  0.308291           -0.055247    0.028288
# new_deaths                    0.338451           -0.035040    0.024954
# total_cases_per_million      -0.055921            0.168203    0.082366
# new_cases_per_million        -0.088389            0.027525    0.058116
# total_deaths_per_million     -0.032383           -0.076574    0.115220
# new_deaths_per_million        0.012117           -0.106091    0.017250
# new_tests                     0.403435            0.066180    0.123837
# total_tests                   0.330375           -0.003957    0.103525
# total_tests_per_thousand      0.040538            0.013101    0.263652
# new_tests_per_thousand       -0.028381            0.082331    0.250472
# tests_per_case               -0.039084           -0.000076    0.103173
# positive_rate                 0.462785            0.058811   -0.079082
# tests_units                   0.374548            0.135897    0.146274
# stringency_index              0.157587           -0.036555   -0.301287
# population                    1.000000            0.108535   -0.138006
# population_density            0.108535            1.000000    0.145517
# median_age                   -0.138006            0.145517    1.000000
# aged_65_older                -0.182623            0.053432    0.905101
# aged_70_older                -0.171125            0.023922    0.891432
# gdp_per_capita               -0.223068            0.272137    0.514325
# extreme_poverty               0.004185            0.004137   -0.518298
# cardiovasc_death_rate         0.126605           -0.150764   -0.416401
# diabetes_prevalence          -0.095169            0.117407    0.217988
# female_smokers               -0.331737           -0.098410    0.473141
# male_smokers                  0.195303            0.031709    0.031161
# handwashing_facilities       -0.088938           -0.028106    0.403738
# hospital_beds_per_thousand   -0.256355           -0.005523    0.668933
# life_expectancy              -0.112497            0.201582    0.808886
# human_development_index      -0.210670            0.147325    0.847193
#
#                             aged_65_older  aged_70_older  gdp_per_capita  \
# total_cases                     -0.122046      -0.124110       -0.036494
# new_cases                       -0.061524      -0.057119       -0.051078
# total_deaths                    -0.023493      -0.022600       -0.007679
# new_deaths                      -0.020315      -0.010099       -0.060098
# total_cases_per_million          0.011747      -0.001035        0.083399
# new_cases_per_million           -0.058117      -0.068219        0.248528
# total_deaths_per_million         0.131778       0.135741        0.010064
# new_deaths_per_million           0.012786       0.013047       -0.085597
# new_tests                        0.040508       0.035364        0.141813
# total_tests                      0.027795       0.022135        0.103372
# total_tests_per_thousand         0.224934       0.226747        0.242348
# new_tests_per_thousand           0.124000       0.128582        0.431646
# tests_per_case                   0.143548       0.134882        0.087432
# positive_rate                   -0.163375      -0.151986        0.045828
# tests_units                      0.073667       0.077124        0.221776
# stringency_index                -0.373370      -0.365112       -0.228532
# population                      -0.182623      -0.171125       -0.223068
# population_density               0.053432       0.023922        0.272137
# median_age                       0.905101       0.891432        0.514325
# aged_65_older                    1.000000       0.993634        0.308396
# aged_70_older                    0.993634       1.000000        0.300405
# gdp_per_capita                   0.308396       0.300405        1.000000
# extreme_poverty                 -0.385574      -0.385803       -0.234422
# cardiovasc_death_rate           -0.384881      -0.378211       -0.447830
# diabetes_prevalence             -0.026071      -0.066668        0.343501
# female_smokers                   0.633231       0.653944        0.184828
# male_smokers                    -0.006849       0.011387       -0.204458
# handwashing_facilities           0.237192       0.219676        0.121147
# hospital_beds_per_thousand       0.642293       0.648004        0.296391
# life_expectancy                  0.685208       0.669034        0.583921
# human_development_index          0.694512       0.684688        0.665536
#
#                             extreme_poverty  cardiovasc_death_rate  \
# total_cases                       -0.082032              -0.015435
# new_cases                         -0.128483              -0.085665
# total_deaths                      -0.131498              -0.063618
# new_deaths                        -0.139489              -0.059618
# total_cases_per_million           -0.122479              -0.148326
# new_cases_per_million             -0.090139              -0.151668
# total_deaths_per_million          -0.152556              -0.159460
# new_deaths_per_million            -0.095019              -0.084711
# new_tests                         -0.134494              -0.111043
# total_tests                       -0.120420              -0.083654
# total_tests_per_thousand          -0.124954              -0.213302
# new_tests_per_thousand            -0.105025              -0.246813
# tests_per_case                     0.015655              -0.143020
# positive_rate                      0.053644              -0.063887
# tests_units                        0.013606              -0.265660
# stringency_index                  -0.002475               0.146672
# population                         0.004185               0.126605
# population_density                 0.004137              -0.150764
# median_age                        -0.518298              -0.416401
# aged_65_older                     -0.385574              -0.384881
# aged_70_older                     -0.385803              -0.378211
# gdp_per_capita                    -0.234422              -0.447830
# extreme_poverty                    1.000000               0.203639
# cardiovasc_death_rate              0.203639               1.000000
# diabetes_prevalence               -0.297279              -0.071605
# female_smokers                    -0.168085              -0.288622
# male_smokers                      -0.154440               0.300407
# handwashing_facilities            -0.498627              -0.183430
# hospital_beds_per_thousand        -0.292944              -0.189085
# life_expectancy                   -0.549105              -0.503583
# human_development_index           -0.561731              -0.529413
#
#                             diabetes_prevalence  female_smokers  male_smokers  \
# total_cases                            0.022010       -0.168224     -0.006830
# new_cases                             -0.037255       -0.174800      0.070914
# total_deaths                          -0.036974       -0.076752     -0.096886
# new_deaths                            -0.054409       -0.125526     -0.056909
# total_cases_per_million                0.106850        0.046538     -0.038231
# new_cases_per_million                  0.239319       -0.052486     -0.089824
# total_deaths_per_million              -0.052624        0.206998     -0.018657
# new_deaths_per_million                -0.014859       -0.015940     -0.136674
# new_tests                              0.100487       -0.107113     -0.025900
# total_tests                            0.073467       -0.105047     -0.112272
# total_tests_per_thousand               0.093215        0.087803     -0.169773
# new_tests_per_thousand                 0.200396        0.056801     -0.147492
# tests_per_case                        -0.040206        0.069572     -0.208319
# positive_rate                         -0.024308       -0.212329      0.086560
# tests_units                           -0.058325       -0.091762     -0.104579
# stringency_index                       0.167912       -0.396350      0.074683
# population                            -0.095169       -0.331737      0.195303
# population_density                     0.117407       -0.098410      0.031709
# median_age                             0.217988        0.473141      0.031161
# aged_65_older                         -0.026071        0.633231     -0.006849
# aged_70_older                         -0.066668        0.653944      0.011387
# gdp_per_capita                         0.343501        0.184828     -0.204458
# extreme_poverty                       -0.297279       -0.168085     -0.154440
# cardiovasc_death_rate                 -0.071605       -0.288622      0.300407
# diabetes_prevalence                    1.000000       -0.130498      0.000912
# female_smokers                        -0.130498        1.000000      0.042459
# male_smokers                           0.000912        0.042459      1.000000
# handwashing_facilities                 0.323416        0.049129      0.078768
# hospital_beds_per_thousand            -0.013527        0.491478      0.139346
# life_expectancy                        0.341564        0.353246     -0.040336
# human_development_index                0.330447        0.412956     -0.102954
#
#                             handwashing_facilities  \
# total_cases                              -0.026241
# new_cases                                -0.038411
# total_deaths                             -0.017790
# new_deaths                               -0.039713
# total_cases_per_million                   0.128168
# new_cases_per_million                     0.080274
# total_deaths_per_million                  0.043282
# new_deaths_per_million                    0.013972
# new_tests                                -0.023443
# total_tests                              -0.019634
# total_tests_per_thousand                  0.000107
# new_tests_per_thousand                    0.015616
# tests_per_case                           -0.015797
# positive_rate                            -0.142791
# tests_units                              -0.089922
# stringency_index                          0.081949
# population                               -0.088938
# population_density                       -0.028106
# median_age                                0.403738
# aged_65_older                             0.237192
# aged_70_older                             0.219676
# gdp_per_capita                            0.121147
# extreme_poverty                          -0.498627
# cardiovasc_death_rate                    -0.183430
# diabetes_prevalence                       0.323416
# female_smokers                            0.049129
# male_smokers                              0.078768
# handwashing_facilities                    1.000000
# hospital_beds_per_thousand                0.231784
# life_expectancy                           0.509525
# human_development_index                   0.434111
#
#                             hospital_beds_per_thousand  life_expectancy  \
# total_cases                                  -0.141119        -0.060717
# new_cases                                    -0.154139         0.075921
# total_deaths                                 -0.077600         0.014391
# new_deaths                                   -0.148543         0.056244
# total_cases_per_million                      -0.005711         0.188150
# new_cases_per_million                        -0.083610         0.181098
# total_deaths_per_million                      0.083089         0.159765
# new_deaths_per_million                       -0.085780         0.022881
# new_tests                                    -0.019164         0.142489
# total_tests                                  -0.065877         0.081313
# total_tests_per_thousand                      0.057029         0.222989
# new_tests_per_thousand                        0.056031         0.272576
# tests_per_case                               -0.002825         0.125830
# positive_rate                                -0.247815        -0.009512
# tests_units                                  -0.051322         0.138804
# stringency_index                             -0.343869        -0.264587
# population                                   -0.256355        -0.112497
# population_density                           -0.005523         0.201582
# median_age                                    0.668933         0.808886
# aged_65_older                                 0.642293         0.685208
# aged_70_older                                 0.648004         0.669034
# gdp_per_capita                                0.296391         0.583921
# extreme_poverty                              -0.292944        -0.549105
# cardiovasc_death_rate                        -0.189085        -0.503583
# diabetes_prevalence                          -0.013527         0.341564
# female_smokers                                0.491478         0.353246
# male_smokers                                  0.139346        -0.040336
# handwashing_facilities                        0.231784         0.509525
# hospital_beds_per_thousand                    1.000000         0.476424
# life_expectancy                               0.476424         1.000000
# human_development_index                       0.584878         0.866364
#
#                             human_development_index
# total_cases                                0.024508
# new_cases                                  0.022887
# total_deaths                               0.098251
# new_deaths                                 0.047348
# total_cases_per_million                    0.207626
# new_cases_per_million                      0.174315
# total_deaths_per_million                   0.205260
# new_deaths_per_million                     0.040168
# new_tests                                  0.195705
# total_tests                                0.175225
# total_tests_per_thousand                   0.330082
# new_tests_per_thousand                     0.389758
# tests_per_case                             0.173331
# positive_rate                             -0.049079
# tests_units                                0.212812
# stringency_index                          -0.293996
# population                                -0.210670
# population_density                         0.147325
# median_age                                 0.847193
# aged_65_older                              0.694512
# aged_70_older                              0.684688
# gdp_per_capita                             0.665536
# extreme_poverty                           -0.561731
# cardiovasc_death_rate                     -0.529413
# diabetes_prevalence                        0.330447
# female_smokers                             0.412956
# male_smokers                              -0.102954
# handwashing_facilities                     0.434111
# hospital_beds_per_thousand                 0.584878
# life_expectancy                            0.866364
# human_development_index                    1.000000

# %% [markdown]
# ## FIX INCOMPLETENESS OF DATASET

# %%
# Removes international and world rows
df = df.drop(df[pd.isna(df.continent)].index)
# Removes rows where labels are NaN
for label in labels:
    df = df.drop(df[pd.isna(df[label])].index)
    

# Transforms test features to 0 if there was not tested (if test_units = 0 then there was not tested yet)
df.loc[df['tests_units'] == 0.00, 
       ['new_tests', 'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_per_case', 'positive_rate']] \
        = 0, 0, 0, 0, 0, 0, 0, 0


# Transforms NaN values to the mean value of that feature
numeric_columns = df.select_dtypes(include='number').columns
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
df[numeric_columns] = pd.DataFrame(imputer.fit_transform(df[numeric_columns]))


# Removes rows where only Iso code etc. are filled
df.dropna(inplace=True)

# ---------------------- TODO: DETECT AND REMOVE OUTLIERS TO IMPROVE PERFORMANCE ------------------------------
## https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba



# Creates labels and features
non_numeric_features = df.select_dtypes(exclude='number').columns
features = df.drop(non_numeric_features, axis=1)
features = features.drop(labels, axis=1)

# %%
## Define what to predict(y) and what to predict by(X) #############
X = features
y = df['new_cases']

## Split data between learning and test data ################
# --- TODO: (not sure if needed for current y because R2 score is high, maybe for other Y) REMOVE BIAS FROM TRAIN AND TEST SPLITS ?  -> SOLVE BY USING K-FOLD ? ------------------------------
x_train,x_test,y_train,y_test = train_test_split(X, y,test_size=0.2, random_state=0)

print('train sizes: X, y')
print(x_train.shape, y_train.shape)
print('test sizes: X, y')
print(x_test.shape, y_test.shape)
# Out:
# train sizes: X, y
# (36564, 25) (36564,)
# test sizes: X, y
# (9141, 25) (9141,)

# %% [markdown]
# ## TRAINING MODEL

# %%
# Train a model
ml = LinearRegression()
ml.fit(x_train, y_train)

# Check coefficients
print('Coefficients:')
print(ml.coef_)

# Check intercept
print('Intercept:')
print(ml.intercept_)
# Out:
# Coefficients:
# [ 3.08885981e-03 -4.34942715e-04  3.16278078e+00  5.22719377e+01
#   9.08233358e-02 -5.23070299e+02 -3.11828412e-02  7.38577478e+03
#  -5.23500886e+02  2.83810412e+00  1.46824760e-06  3.96055641e-03
#   9.22320147e+01  2.24761561e+01 -2.34012518e+02 -1.89489056e-02
#  -8.91919092e+00 -9.90125864e-01 -3.46483969e+01  1.22819601e+01
#  -2.31112118e+01 -4.55275495e+00 -4.97973415e+01  1.66879831e+01
#   4.66696397e+02]
# Intercept:
# -1247.8917678696569

# %% [markdown]
# ## MODEL PERFORMANCE

# %%
# Predict y
y_predicted = ml.predict(x_test)
print('Y predicted size')

# Validate predicted y
print('R2 Score:')
print(r2_score(y_test, y_predicted))
print('Mean squared error (MSE)', mean_squared_error(y_test, y_predicted))

# Display differences in numbers
pred_y_df = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_predicted, 'Difference': y_test - y_predicted})
print(pred_y_df[0:20])
# Out:
# Y predicted size
# R2 Score:
# 0.7531699465898111
# Mean squared error (MSE) 5526024.475749199
#        Actual value  Predicted value   Difference
# 11240        1303.0      1100.018065   202.981935
# 34961        4248.0      2927.184959  1320.815041
# 31403          69.0       105.163201   -36.163201
# 10960          17.0      -166.619856   183.619856
# 13021         932.0       887.785105    44.214895
# 11621           6.0       558.688954  -552.688954
# 39983          16.0       -11.243863    27.243863
# 16263           2.0      -522.177293   524.177293
# 34730        1830.0       900.710107   929.289893
# 15027           0.0       184.455532  -184.455532
# 9350            3.0      -930.956677   933.956677
# 16717         209.0      2327.114295 -2118.114295
# 771             0.0       244.376845  -244.376845
# 46577           0.0        80.527628   -80.527628
# 2789          497.0      -101.803340   598.803340
# 32129           0.0        16.844498   -16.844498
# 17101         154.0       109.141251    44.858749
# 15273         467.0      2098.296793 -1631.296793
# 7369           95.0      -263.726552   358.726552
# 44601           0.0       315.594779  -315.594779

# %% [markdown]
# ## INSIGHTS

# %%
#----------------- TODO: Visualize more insights -> causes for cases and deaths -------------------
# Visualize the validation results
plt.figure(figsize=(15, 10))
plt.scatter(y_test, y_predicted)
plt.xlabel('predicted')
plt.ylabel('actual')
plt.title('Predicted new cases vs Actual new cases')
plt.show()


# Visualize Insight 1:
plt.figure(figsize=(15, 10))
plt.xlabel('Median age')
plt.ylabel('New cases')
plt.title('PREDICTED: Median age vs new cases')
plt.scatter(x_test['median_age'], y_predicted, color='blue')
plt.show()

plt.figure(figsize=(15, 10))
plt.xlabel('Median age')
plt.ylabel('New cases')
plt.title('ACTUAL: Median age vs new cases')
plt.scatter(x_test['median_age'], y_test, color='yellow')
plt.show()
